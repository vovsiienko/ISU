# %% [markdown]
# <a href="https://colab.research.google.com/github/vovsiienko/IT496_Course_acitvities/blob/master/IT496_ViktoriiaO_Risk_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import a few libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

#Create a dataframe (data table)
riskDF = pd.DataFrame(columns=['risk', 'likelihood', 'impact', 'score'])

# %%
riskDF['risk']=['service don times', 'team member leaves', 'budget cuts', 'security breach incidents']
riskDF['likelihood']=[0.2,0.3,0.1,0.5]
riskDF['impact']=[5,2,4,1]
riskDF['score']=riskDF['impact']*riskDF['likelihood']
scoresPivot=riskDF.pivot('impact', 'likelihood', 'score')
print(scoresPivot)
labelsPivot=riskDF.pivot('impact', 'likelihood', 'risk')
print(labelsPivot)
# Out:
# likelihood  0.1  0.2  0.3  0.5
# impact
# 1           NaN  NaN  NaN  0.5
# 2           NaN  NaN  0.6  NaN
# 4           0.4  NaN  NaN  NaN
# 5           NaN  1.0  NaN  NaN
# likelihood          0.1                0.2                 0.3  \
# impact
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN  team member leaves
# 4           budget cuts                NaN                 NaN
# 5                   NaN  service don times                 NaN
#
# likelihood                        0.5
# impact
# 1           security breach incidents
# 2                                 NaN
# 4                                 NaN
# 5                                 NaN

# %%
#simple heatmap
sns.set(rc={'figure.figsize':(12,6)})
p1=sns.heatmap(scoresPivot, cmap="icefire_r", annot=labelsPivot, fmt='')
