# %% [markdown]
# <a href="https://colab.research.google.com/github/vovsiienko/IT496_Course_acitvities/blob/master/IT496_ViktoriiaO_Assignment5_DuPontAnalysis_Nvidia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

myAPIKey = '6e7abf1b234f34338f72bf5742f79107'

#NVIDIA
stock = 'NVDA'

balanceStatements = requests.get (f"https://financialmodelingprep.com/api/v3/balance-sheet-statement/{stock}?apikey={myAPIKey}").json()
                                  
incomeStatements = requests.get (f"https://financialmodelingprep.com/api/v3/income-statement/{stock}?apikey={myAPIKey}").json()
                                 
print (balanceStatements[:3])
# Out:
# [{'date': '2022-01-30', 'symbol': 'NVDA', 'reportedCurrency': 'USD', 'cik': '0001045810', 'fillingDate': '2022-03-18', 'acceptedDate': '2022-02-16', 'calendarYear': '2022', 'period': 'FY', 'cashAndCashEquivalents': 1990000000, 'shortTermInvestments': 19218000000, 'cashAndShortTermInvestments': 21208000000, 'netReceivables': 4650000000, 'inventory': 2605000000, 'otherCurrentAssets': 366000000, 'totalCurrentAssets': 28829000000, 'propertyPlantEquipmentNet': 3607000000, 'goodwill': 4349000000, 'intangibleAssets': 2339000000, 'goodwillAndIntangibleAssets': 6688000000, 'longTermInvestments': 266000000, 'taxAssets': 1222000000, 'otherNonCurrentAssets': 3575000000, 'totalNonCurrentAssets': 15358000000, 'otherAssets': 0.0, 'totalAssets': 44187000000, 'accountPayables': 1783000000, 'shortTermDebt': 0.0, 'taxPayables': 0.0, 'deferredRevenue': 300000000, 'otherCurrentLiabilities': 2252000000, 'totalCurrentLiabilities': 4335000000, 'longTermDebt': 11687000000, 'deferredRevenueNonCurrent': 202000000, 'deferredTaxLiabilitiesNonCurrent': 245000000, 'otherNonCurrentLiabilities': 1106000000, 'totalNonCurrentLiabilities': 13240000000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 741000000, 'totalLiabilities': 17575000000, 'preferredStock': 0.0, 'commonStock': 3000000.0, 'retainedEarnings': 16235000000, 'accumulatedOtherComprehensiveIncomeLoss': -11000000, 'othertotalStockholdersEquity': 10385000000, 'totalStockholdersEquity': 26612000000, 'totalLiabilitiesAndStockholdersEquity': 44187000000, 'minorityInterest': 0, 'totalEquity': 26612000000, 'totalLiabilitiesAndTotalEquity': 44187000000, 'totalInvestments': 19484000000, 'totalDebt': 11687000000, 'netDebt': 9697000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130.htm'}, {'date': '2021-01-31', 'symbol': 'NVDA', 'reportedCurrency': 'USD', 'cik': '0001045810', 'fillingDate': '2021-02-26', 'acceptedDate': '2021-02-26 17:03:14', 'calendarYear': '2021', 'period': 'FY', 'cashAndCashEquivalents': 847000000, 'shortTermInvestments': 10714000000, 'cashAndShortTermInvestments': 11561000000, 'netReceivables': 2429000000, 'inventory': 1826000000, 'otherCurrentAssets': 239000000, 'totalCurrentAssets': 16055000000, 'propertyPlantEquipmentNet': 2856000000, 'goodwill': 4193000000, 'intangibleAssets': 2737000000, 'goodwillAndIntangibleAssets': 6930000000, 'longTermInvestments': 144000000, 'taxAssets': 806000000, 'otherNonCurrentAssets': 2000000000, 'totalNonCurrentAssets': 12736000000, 'otherAssets': 0.0, 'totalAssets': 28791000000, 'accountPayables': 1201000000, 'shortTermDebt': 1120000000, 'taxPayables': 61000000, 'deferredRevenue': 288000000, 'otherCurrentLiabilities': 1316000000, 'totalCurrentLiabilities': 3925000000, 'longTermDebt': 5964000000, 'deferredRevenueNonCurrent': 163000000, 'deferredTaxLiabilitiesNonCurrent': 241000000, 'otherNonCurrentLiabilities': 1605000000, 'totalNonCurrentLiabilities': 7973000000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 755000000, 'totalLiabilities': 11898000000, 'preferredStock': 0.0, 'commonStock': 1000000.0, 'retainedEarnings': 18908000000, 'accumulatedOtherComprehensiveIncomeLoss': 19000000, 'othertotalStockholdersEquity': -2035000000, 'totalStockholdersEquity': 16893000000, 'totalLiabilitiesAndStockholdersEquity': 28791000000, 'minorityInterest': 0, 'totalEquity': 16893000000, 'totalLiabilitiesAndTotalEquity': 28791000000, 'totalInvestments': 10858000000, 'totalDebt': 7084000000, 'netDebt': 6237000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/0001045810-21-000010-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131.htm'}, {'date': '2020-01-26', 'symbol': 'NVDA', 'reportedCurrency': 'USD', 'cik': '0001045810', 'fillingDate': '2020-02-20', 'acceptedDate': '2020-02-20 16:38:18', 'calendarYear': '2020', 'period': ' ...

# %%
#the numbers from the three most recent years
threeYearBalanceStatements = balanceStatements[:3]
threeYearIncomeStatements = incomeStatements[:3]

# %%
#calculate profitability, assesTurnOver, and capitaStructure
#this is net income/sales - first fraction in DuPont analysis framework
profitability=[]
#this is net sales/assests - second fraction
assetTurnOver=[]
#this is assests/avg. shareholders equity  - third fraction
capitalStructure=[]
#the result of DuPontAnalysis
returnOnEquity = []
#dates
dates = []

#getting details
for i in range (0,3):
  #datesValue =threeYearBalanceStatements[i]['date']
  #dates.append(datesValue)

  dates.append(threeYearBalanceStatements[i]['date'])

  profitabilityValue=round((threeYearIncomeStatements[i]['netIncome']/threeYearIncomeStatements[i]['revenue']),2)
  profitability.append(profitabilityValue)
  
  assetTurnOverValue=round((threeYearIncomeStatements[i]['revenue']/threeYearBalanceStatements[i]['totalAssets']),2)
  assetTurnOver.append(assetTurnOverValue)

  capitalStructureValue=round((threeYearBalanceStatements[i]['totalAssets']/threeYearBalanceStatements[i]['totalStockholdersEquity']),2)
  capitalStructure.append(capitalStructureValue)

  returnOnEquityValue=round((profitabilityValue*assetTurnOverValue*capitalStructureValue),2)
  returnOnEquity.append(returnOnEquityValue)

print(returnOnEquity)
# Out:
# [0.36, 0.26, 0.23]

# %%
from numpy.ma.core import sort
from datetime import date
from pandas.core.arrays import datetimes
DuPontDF = pd.DataFrame(columns=['date','profitability', 'assetTurnOver', 'capitalStructure', 'returnOnEquity'])

DuPontDF['date']=dates
DuPontDF['profitability']=profitability
DuPontDF['assetTurnOver']=assetTurnOver
DuPontDF['capitalStructure']=capitalStructure
DuPontDF['returnOnEquity']=returnOnEquity

DuPontDF = DuPontDF.sort_values(by='date', ascending=True)

print(DuPontDF)
# Out:
#          date  profitability  assetTurnOver  capitalStructure  returnOnEquity
# 2  2020-01-26           0.26           0.63              1.42            0.23
# 1  2021-01-31           0.26           0.58              1.70            0.26
# 0  2022-01-30           0.36           0.61              1.66            0.36

# %%
DuPontDF.plot(x='date', y='returnOnEquity', kind='line')
plt.title('DuPont Analysis - NVIDIA')
plt.xlabel('Date')
plt.ylabel('Return On Equity')
plt.show()

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
#set x for all them
x=DuPontDF['date']

#top left
axs[0,0].plot(x,DuPontDF['profitability'],'tab:green')
axs[0,0].set_title('profitability')

#top right
axs[0,1].plot(x,DuPontDF['assetTurnOver'])
axs[0,1].set_title('assetTurnOver')

#bottom left
axs[1,0].plot(x,DuPontDF['capitalStructure'], 'tab:purple')
axs[1,0].set_title('capitalStructure')

#bottom right
axs[1,1].plot(x,DuPontDF['returnOnEquity'], 'tab:red')
axs[1,1].set_title('returnOnEquity')

fig.tight_layout()
